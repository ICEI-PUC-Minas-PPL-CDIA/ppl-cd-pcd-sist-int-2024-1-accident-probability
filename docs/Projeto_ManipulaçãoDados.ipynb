# %%
import pandas as pd
import numpy as np

# %%
dados = pd.read_csv("/content/car_accidentOFICIAL.csv")   # declaração da variável >dados<

# %%
dados                                                     # variável >dados< rodada
# Out:
#          Count    Accident_ID Accident_Date Day_of_Week  \
# 0            0  200901BS70001    2021-01-01    Thursday
# 1            1  200901BS70002    2021-01-05      Monday
# 2            2  200901BS70003    2021-01-04      Sunday
# 3            3  200901BS70004    2021-01-05      Monday
# 4            4  200901BS70005    2021-01-06     Tuesday
# ...        ...            ...           ...         ...
# 307968  307968  201091NM01760    2022-02-18    Thursday
# 307969  307969  201091NM01881    2022-02-21      Sunday
# 307970  307970  201091NM01935    2022-02-23     Tuesday
# 307971  307971  201091NM01964    2022-02-23     Tuesday
# 307972  307972  201091NM02142    2022-02-28      Sunday
#
#                             Junction_Detail Accident_Injuries  \
# 0                   T or staggered junction           Serious
# 1                                Crossroads           Serious
# 2                   T or staggered junction            Slight
# ...

# %% [markdown]
# ## 1- Remoção de Dados Omissos

# %%
dados.tail()     # retorno das últimas linhas do DataFrame (etapa de verificação, pra checar se está tudo em ordem)
# Out:
#          Count    Accident_ID Accident_Date Day_of_Week  \
# 307968  307968  201091NM01760    2022-02-18    Thursday
# 307969  307969  201091NM01881    2022-02-21      Sunday
# 307970  307970  201091NM01935    2022-02-23     Tuesday
# 307971  307971  201091NM01964    2022-02-23     Tuesday
# 307972  307972  201091NM02142    2022-02-28      Sunday
#
#                             Junction_Detail Accident_Injuries  \
# 307968  Not at junction or within 20 metres            Slight
# 307969  Not at junction or within 20 metres            Slight
# 307970              T or staggered junction            Slight
# 307971              T or staggered junction           Serious
# 307972              T or staggered junction           Serious
#
#               Light_Conditions  Number_of_Casualties  Number_of_Vehicles  \
# 307968                Daylight                     2                   1
# 307969  Darkness - no lighting                     1                   1
# ...

# %%
dados.info()    # informações gerais da base de dados
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307973 entries, 0 to 307972
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Count                    307973 non-null  int64
#  1   Accident_ID              307973 non-null  object
#  2   Accident_Date            307973 non-null  object
#  3   Day_of_Week              307973 non-null  object
#  4   Junction_Detail          307973 non-null  object
#  5   Accident_Injuries        307973 non-null  object
#  6   Light_Conditions         307973 non-null  object
#  7   Number_of_Casualties     307973 non-null  int64
#  8   Number_of_Vehicles       307973 non-null  int64
#  9   Road_Surface_Conditions  307973 non-null  object
#  10  Road_Type                307973 non-null  object
#  11  Speed_limit              307973 non-null  int64
#  12  Hour_of_Accident         307973 non-null  float64
# ...

# %%
dados.isnull()        # verificando se existem valores nulos (ou ausentes) no DataFrame*
# Out:
#         Count  Accident_ID  Accident_Date  Day_of_Week  Junction_Detail  \
# 0       False        False          False        False            False
# 1       False        False          False        False            False
# 2       False        False          False        False            False
# 3       False        False          False        False            False
# 4       False        False          False        False            False
# ...       ...          ...            ...          ...              ...
# 307968  False        False          False        False            False
# 307969  False        False          False        False            False
# 307970  False        False          False        False            False
# 307971  False        False          False        False            False
# 307972  False        False          False        False            False
#
#         Accident_Injuries  Light_Conditions  Number_of_Casualties  \
# ...

# %%
dados.isnull().sum()   # verificando a quantidade de valores nulos no DataFrame — (nenhum)*
# Out:
# Count                      0
# Accident_ID                0
# Accident_Date              0
# Day_of_Week                0
# Junction_Detail            0
# Accident_Injuries          0
# Light_Conditions           0
# Number_of_Casualties       0
# Number_of_Vehicles         0
# Road_Surface_Conditions    0
# Road_Type                  0
# Speed_limit                0
# Hour_of_Accident           0
# Urban_or_Rural_Area        0
# Weather_Conditions         0
# Vehicle_Type               0
# dtype: int64

# %%
dados = dados.dropna()   # eliminando (cegamente) valores nulos — mas não tinha, nesse caso*

# %% [markdown]
# ## 2- Discretização de Dados

# %%
dados
# Out:
#          Count    Accident_ID Accident_Date Day_of_Week  \
# 0            0  200901BS70001    2021-01-01    Thursday
# 1            1  200901BS70002    2021-01-05      Monday
# 2            2  200901BS70003    2021-01-04      Sunday
# 3            3  200901BS70004    2021-01-05      Monday
# 4            4  200901BS70005    2021-01-06     Tuesday
# ...        ...            ...           ...         ...
# 307968  307968  201091NM01760    2022-02-18    Thursday
# 307969  307969  201091NM01881    2022-02-21      Sunday
# 307970  307970  201091NM01935    2022-02-23     Tuesday
# 307971  307971  201091NM01964    2022-02-23     Tuesday
# 307972  307972  201091NM02142    2022-02-28      Sunday
#
#                             Junction_Detail Accident_Injuries  \
# 0                   T or staggered junction           Serious
# 1                                Crossroads           Serious
# 2                   T or staggered junction            Slight
# ...

# %%
dados["Speed_limit"]                # volta os valores presentes na coluna "Speed_limit", formando uma series
# Out:
# 0         30
# 1         30
# 2         30
# 3         30
# 4         30
#           ..
# 307968    60
# 307969    60
# 307970    30
# 307971    60
# 307972    60
# Name: Speed_limit, Length: 307973, dtype: int64

# %%
dados["Speed_limit"].value_counts() # contagem das variáveis numéricas da coluna "Speed_limit"
# Out:
# Speed_limit
# 30    200040
# 60     46826
# 40     25650
# 70     22362
# 50     10191
# 20      2899
# 10         3
# 15         2
# Name: count, dtype: int64

# %%
dados["Speed_limit"].unique()       # volta os valores únicos que aparecem na coluna "Speed_limit"
# Out:
# array([30, 20, 50, 40, 70, 60, 10, 15])

# %%
dados["Speed_limit"].describe()     # fornece a contagem, a média (mean), o desvio padrão (sdt), o valor mínimo,
                                    # o quartil de 25%/50%/75% e o valor máximo da coluna "Speed_limit"
# Out:
# count    307973.000000
# mean         38.866037
# std          14.032933
# min          10.000000
# 25%          30.000000
# 50%          30.000000
# 75%          50.000000
# max          70.000000
# Name: Speed_limit, dtype: float64

# %%
dados[dados["Speed_limit"] == 30]   # mostra quais valores na coluna "Speed_limit" são iguais 30
# Out:
#          Count    Accident_ID Accident_Date Day_of_Week  \
# 0            0  200901BS70001    2021-01-01    Thursday
# 1            1  200901BS70002    2021-01-05      Monday
# 2            2  200901BS70003    2021-01-04      Sunday
# 3            3  200901BS70004    2021-01-05      Monday
# 4            4  200901BS70005    2021-01-06     Tuesday
# ...        ...            ...           ...         ...
# 307940  307940  201091NL05987    2022-10-26     Tuesday
# 307942  307942  201091NL06327    2022-11-12      Friday
# 307945  307945  201091NL06820    2022-12-04    Saturday
# 307964  307964  201091NM00939    2022-01-25      Monday
# 307970  307970  201091NM01935    2022-02-23     Tuesday
#
#                             Junction_Detail Accident_Injuries  \
# 0                   T or staggered junction           Serious
# 1                                Crossroads           Serious
# 2                   T or staggered junction            Slight
# ...

# %%
dados[dados["Speed_limit"] < 30]    # mostra quais valores na coluna "Speed_limit" são menores que 30
# Out:
#          Count    Accident_ID Accident_Date Day_of_Week  \
# 27          27  200901BS70033    2021-01-31    Saturday
# 1508      1508  200901CW10790    2021-05-01      Friday
# 1710      1710  200901CW11050    2021-06-03   Wednesday
# 2003      2003  200901CW11457    2021-07-20      Monday
# 2259      2259  200901CW11822    2021-09-07      Monday
# ...        ...            ...           ...         ...
# 306264  306264  201063AC03810    2022-02-03   Wednesday
# 307476  307476  201063DP22110    2022-07-26      Monday
# 307818  307818  201091NJ01882    2022-02-10   Wednesday
# 307907  307907  201091NK03455    2022-07-13     Tuesday
# 307917  307917  201091NK05608    2022-11-05      Friday
#
#                             Junction_Detail Accident_Injuries  \
# 27                               Crossroads            Slight
# 1508                T or staggered junction             Fatal
# 1710                             Crossroads            Slight
# ...

# %%
dados[(dados['Speed_limit'] < 30)&(dados['Light_Conditions'] == 'Daylight')] # mostra quais valores na coluna "Speed_limit" são menores que 30
                                                                             # e quais valores na coluna 'Light_Conditions' são iguais 'Daylight'
# Out:
#          Count    Accident_ID Accident_Date Day_of_Week  \
# 27          27  200901BS70033    2021-01-31    Saturday
# 1508      1508  200901CW10790    2021-05-01      Friday
# 1710      1710  200901CW11050    2021-06-03   Wednesday
# 2003      2003  200901CW11457    2021-07-20      Monday
# 2259      2259  200901CW11822    2021-09-07      Monday
# ...        ...            ...           ...         ...
# 305901  305901       2.01E+12    2022-11-25    Thursday
# 306264  306264  201063AC03810    2022-02-03   Wednesday
# 307476  307476  201063DP22110    2022-07-26      Monday
# 307818  307818  201091NJ01882    2022-02-10   Wednesday
# 307907  307907  201091NK03455    2022-07-13     Tuesday
#
#                             Junction_Detail Accident_Injuries  \
# 27                               Crossroads            Slight
# 1508                T or staggered junction             Fatal
# 1710                             Crossroads            Slight
# ...

# %%
dados.replace({"Daylight":"Day"}) # substituição dos valores: Daylight passa a ser apenas Day*
# Out:
#          Count    Accident_ID Accident_Date Day_of_Week  \
# 0            0  200901BS70001    2021-01-01    Thursday
# 1            1  200901BS70002    2021-01-05      Monday
# 2            2  200901BS70003    2021-01-04      Sunday
# 3            3  200901BS70004    2021-01-05      Monday
# 4            4  200901BS70005    2021-01-06     Tuesday
# ...        ...            ...           ...         ...
# 307968  307968  201091NM01760    2022-02-18    Thursday
# 307969  307969  201091NM01881    2022-02-21      Sunday
# 307970  307970  201091NM01935    2022-02-23     Tuesday
# 307971  307971  201091NM01964    2022-02-23     Tuesday
# 307972  307972  201091NM02142    2022-02-28      Sunday
#
#                             Junction_Detail Accident_Injuries  \
# 0                   T or staggered junction           Serious
# 1                                Crossroads           Serious
# 2                   T or staggered junction            Slight
# ...

# %%
len(dados['Hour_of_Accident'].unique()) # retorna uma matriz de valores únicos presentes na coluna 'Hour_of_Accident'
                                        # calcula o comprimento dessa matriz, ou seja, o número de valores únicos presentes na coluna
# Out:
# 24

# %%
dados['Hour_of_Accident'].value_counts()  # conta o número de ocorrências de valores únicos na series 'Hour_of_Accident'
                                          # útil para entender a distribuição dos dados em uma coluna e identificar quais valores são mais comuns
# Out:
# Hour_of_Accident
# 17.0    26964
# 16.0    24903
# 15.0    24151
# 8.0     22552
# 18.0    21063
# 14.0    19084
# 13.0    18971
# 12.0    18342
# 11.0    16141
# 19.0    15851
# 9.0     15560
# 10.0    13791
# 7.0     12560
# 20.0    11402
# 21.0     9443
# 22.0     8146
# 23.0     6400
# 6.0      5274
# 0.0      4667
# 1.0      3533
# 2.0      2652
# 5.0      2491
# 3.0      2311
# 4.0      1721
# Name: count, dtype: int64

# %%
dados['Number_of_Casualties'].unique() # volta os valores únicos que aparecem na coluna 'Number_of_Casualties'
# Out:
# array([ 1, 11,  3,  2,  4,  5,  6, 10,  8,  7,  9, 13, 12, 14, 16, 18, 15,
#        19, 21, 17, 27, 48, 40, 24, 26, 22, 42, 43])

# %%
dados['Number_of_Vehicles'].unique()   # volta os valores únicos que aparecem na coluna 'Number_of_Vehicles'
# Out:
# array([ 2,  1,  3,  4,  5,  9,  6,  8,  7, 10, 16, 13, 14, 11, 12, 32, 19])

# %%
for i in dados['Hour_of_Accident']:
  if (i <= 3) &(i >= 0):
   dados['Hour_of_Accident'] =  dados['Hour_of_Accident'].replace({i:"0-3"})
  if (i <= 6) & (i > 3 ):
    dados ['Hour_of_Accident'] =  dados['Hour_of_Accident'].replace({i:"3-6"})
  if (i <= 9) & (i > 6):
    dados ['Hour_of_Accident'] =  dados['Hour_of_Accident'].replace({i:"6-9"})
  if (i <= 12) & (i > 9):
    dados ['Hour_of_Accident'] =  dados['Hour_of_Accident'].replace({i:"9-12"})
  if (i <= 15) & (i > 12):
    dados ['Hour_of_Accident'] =  dados['Hour_of_Accident'].replace({i:"12-15"})
  if (i <= 18) & (i > 15):
    dados ['Hour_of_Accident'] =  dados['Hour_of_Accident'].replace({i:"15-18"})
  if (i <= 21) & (i > 18):
    dados ['Hour_of_Accident'] =  dados['Hour_of_Accident'].replace({i:"18-21"})
  if (i <= 24) & (i > 21):
    dados ['Hour_of_Accident'] =  dados['Hour_of_Accident'].replace({i:"21-24"})

# %%
dados['Hour_of_Accident'] # checando se a faixa de valores deu certo*
# Out:
# 0         12-15
# 1          9-12
# 2         12-15
# 3           6-9
# 4         15-18
#           ...
# 307968      6-9
# 307969      0-3
# 307970      6-9
# 307971    15-18
# 307972    12-15
# Name: Hour_of_Accident, Length: 307973, dtype: object

# %% [markdown]
# ## 3- Remoção de Outliers

# %%
dados
# Out:
#          Count    Accident_ID Accident_Date Day_of_Week  \
# 0            0  200901BS70001    2021-01-01    Thursday
# 1            1  200901BS70002    2021-01-05      Monday
# 2            2  200901BS70003    2021-01-04      Sunday
# 3            3  200901BS70004    2021-01-05      Monday
# 4            4  200901BS70005    2021-01-06     Tuesday
# ...        ...            ...           ...         ...
# 307968  307968  201091NM01760    2022-02-18    Thursday
# 307969  307969  201091NM01881    2022-02-21      Sunday
# 307970  307970  201091NM01935    2022-02-23     Tuesday
# 307971  307971  201091NM01964    2022-02-23     Tuesday
# 307972  307972  201091NM02142    2022-02-28      Sunday
#
#                             Junction_Detail Accident_Injuries  \
# 0                   T or staggered junction           Serious
# 1                                Crossroads           Serious
# 2                   T or staggered junction            Slight
# ...

# %%
dados.replace({"Daylight":"Day"}) # substituição dos valores: Daylight passa a ser apenas Day* (de novo)
# Out:
#          Count    Accident_ID Accident_Date Day_of_Week  \
# 0            0  200901BS70001    2021-01-01    Thursday
# 1            1  200901BS70002    2021-01-05      Monday
# 2            2  200901BS70003    2021-01-04      Sunday
# 3            3  200901BS70004    2021-01-05      Monday
# 4            4  200901BS70005    2021-01-06     Tuesday
# ...        ...            ...           ...         ...
# 307968  307968  201091NM01760    2022-02-18    Thursday
# 307969  307969  201091NM01881    2022-02-21      Sunday
# 307970  307970  201091NM01935    2022-02-23     Tuesday
# 307971  307971  201091NM01964    2022-02-23     Tuesday
# 307972  307972  201091NM02142    2022-02-28      Sunday
#
#                             Junction_Detail Accident_Injuries  \
# 0                   T or staggered junction           Serious
# 1                                Crossroads           Serious
# 2                   T or staggered junction            Slight
# ...

# %%
dados ['Number_of_Casualties'].value_counts() # retorna uma series que mostra quantas vezes cada valor único aparece na coluna 'Number_of_Casualties'
# Out:
# Number_of_Casualties
# 1     235093
# 2      50088
# 3      14338
# 4       5348
# 5       1896
# 6        713
# 7        242
# 8        102
# 9         44
# 10        34
# 12        15
# 11        14
# 13        10
# 14         8
# 17         5
# 18         4
# 21         3
# 16         3
# 15         3
# 24         2
# 19         1
# 27         1
# 48         1
# 40         1
# 26         1
# 22         1
# 42         1
# 43         1
# Name: count, dtype: int64

# %%
dados['Vehicle_Type'].unique()                # volta os valores únicos que aparecem na coluna 'Vehicle_Type
# Out:
# array(['Car', 'Taxi', 'Motorcycle', 'Van', 'Other', 'Bus', 'Pedal cycle',
#        'Ridden horse'], dtype=object)

# %%
dados [(dados ['Number_of_Casualties'] > 10)&(dados['Number_of_Vehicles'] < 2)]['Vehicle_Type'] # retorna a series de valores na coluna 'Vehicle_Type' para as linhas onde
                                                                                                # o número de vítimas é maior que 10 e o número de veículos é menor que 2*
# Out:
# 26567            Car
# 45818            Car
# 60680            Car
# 69214            Car
# 90411            Car
# 131785           Van
# 195813           Car
# 201184    Motorcycle
# 215152          Taxi
# 223638    Motorcycle
# 254965           Car
# 264747         Other
# 267102           Car
# 281743           Car
# 301608           Car
# Name: Vehicle_Type, dtype: object

# %%
dados [(dados ['Number_of_Casualties'] > 10)&(dados['Number_of_Vehicles'] < 2)].index # retorna os índices das linhas que atendem às condições especificadas*
# Out:
# Index([ 26567,  45818,  60680,  69214,  90411, 131785, 195813, 201184, 215152,
#        223638, 254965, 264747, 267102, 281743, 301608],
#       dtype='int64')

# %%
dados = dados.drop([26567, 45818, 60680, 69214, 90411, 131785]) # remove as linhas com os índices 26567, 45818, 60680, 69214, 90411 e 131785 do
                                                                # DataFrame dados, e armazena o DataFrame resultante de volta na variável dados*

# %%
dados[26565:26569] # conferindo se a remoção de outliers deu certo*
# Out:
#        Count    Accident_ID Accident_Date Day_of_Week  \
# 26565  26565  200904CJ09066    2021-10-10    Saturday
# 26566  26566  200904CJ09067    2021-10-08    Thursday
# 26568  26568  200904CJ09069    2021-10-21   Wednesday
# 26569  26569  200904CJ09070    2021-10-22    Thursday
#
#                            Junction_Detail Accident_Injuries Light_Conditions  \
# 26565              T or staggered junction            Slight         Daylight
# 26566                           Roundabout            Slight         Daylight
# 26568  Not at junction or within 20 metres           Serious         Daylight
# 26569              T or staggered junction            Slight         Daylight
#
#        Number_of_Casualties  Number_of_Vehicles Road_Surface_Conditions  \
# 26565                     1                   2                     Dry
# 26566                     1                   2                     Dry
# 26568                     1                   2                     Dry
# ...

# %%
from google.colab import files

# %%
df = pd.DataFrame(dados)

# %%
df.to_csv('car_accidentOFICIAL.csv', index=False)

# %%
files.download('car_accidentOFICIAL.csv')
