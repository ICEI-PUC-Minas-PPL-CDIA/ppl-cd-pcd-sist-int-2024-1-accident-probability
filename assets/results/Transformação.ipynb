# %%
import pandas as pd
import numpy as np

# %%
dados = pd.read_csv("car_accident.csv")

# %%
dados
# Out:
#         Unnamed: 0    Accident_ID Accident Date Day_of_Week  \
# 0                0  200901BS70001    2021-01-01    Thursday
# 1                1  200901BS70002    2021-01-05      Monday
# 2                2  200901BS70003    2021-01-04      Sunday
# 3                3  200901BS70004    2021-01-05      Monday
# 4                4  200901BS70005    2021-01-06     Tuesday
# ...            ...            ...           ...         ...
# 168297      168297  201001GD10330    2022-05-25     Tuesday
# 168298      168298  201001GD10331    2022-05-26   Wednesday
# 168299      168299  201001GD10332    2022-05-12   Wednesday
# 168300      168300  201001GD10334    2022-05-26   Wednesday
# 168301          16            NaN           NaN         NaN
#
#                             Junction_Detail Accident_Injuries  \
# 0                   T or staggered junction           Serious
# 1                                Crossroads           Serious
# ...

# %% [markdown]
# # Remoção de dados omissos

# %%
  dados.tail()
# Out:
#         Unnamed: 0    Accident_ID Accident Date Day_of_Week  \
# 168297      168297  201001GD10330    2022-05-25     Tuesday
# 168298      168298  201001GD10331    2022-05-26   Wednesday
# 168299      168299  201001GD10332    2022-05-12   Wednesday
# 168300      168300  201001GD10334    2022-05-26   Wednesday
# 168301          16            NaN           NaN         NaN
#
#                             Junction_Detail Accident_Injuries  \
# 168297  Not at junction or within 20 metres            Slight
# 168298              T or staggered junction            Slight
# 168299              T or staggered junction            Slight
# 168300                           Crossroads            Slight
# 168301                                  NaN               NaN
#
#                    Light_Conditions  death_toll  Number_of_Vehicles  \
# 168297                     Daylight         1.0                 1.0
# 168298                     Daylight         1.0                 2.0
# ...

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168302 entries, 0 to 168301
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Unnamed: 0               168302 non-null  int64
#  1   Accident_ID              168301 non-null  object
#  2   Accident Date            168301 non-null  object
#  3   Day_of_Week              168301 non-null  object
#  4   Junction_Detail          168301 non-null  object
#  5   Accident_Injuries        168301 non-null  object
#  6   Light_Conditions         168301 non-null  object
#  7   death_toll               168301 non-null  float64
#  8   Number_of_Vehicles       168301 non-null  float64
#  9   Road_Surface_Conditions  168301 non-null  object
#  10  Road_Type                168301 non-null  object
#  11  Speed_limit              168301 non-null  float64
#  12  Hour_of_Accident         168301 non-null  float64
# ...

# %%
dados.isnull()
# Out:
#         Unnamed: 0  Accident_ID  Accident Date  Day_of_Week  Junction_Detail  \
# 0            False        False          False        False            False
# 1            False        False          False        False            False
# 2            False        False          False        False            False
# 3            False        False          False        False            False
# 4            False        False          False        False            False
# ...            ...          ...            ...          ...              ...
# 168297       False        False          False        False            False
# 168298       False        False          False        False            False
# 168299       False        False          False        False            False
# 168300       False        False          False        False            False
# 168301       False         True           True         True             True
#
# ...

# %%
dados.isnull().sum()
# Out:
# Unnamed: 0                 0
# Accident_ID                1
# Accident Date              1
# Day_of_Week                1
# Junction_Detail            1
# Accident_Injuries          1
# Light_Conditions           1
# death_toll                 1
# Number_of_Vehicles         1
# Road_Surface_Conditions    1
# Road_Type                  1
# Speed_limit                1
# Hour_of_Accident           1
# Urban_or_Rural_Area        1
# Weather_Conditions         1
# Vehicle_Type               1
# dtype: int64

# %%
dados = dados.dropna() #eliminando (cegamente) valores nulos

# %% [markdown]
# # Discretização de dados
# O uso da discretização de dados é aplicado para otimizar o uso de dados numericos por algoritimos de classificação e ajudar a melhorar a interpretabilidade do modelo.

# %%
dados
# Out:
#         Unnamed: 0    Accident_ID Accident Date Day_of_Week  \
# 0                0  200901BS70001    2021-01-01    Thursday
# 1                1  200901BS70002    2021-01-05      Monday
# 2                2  200901BS70003    2021-01-04      Sunday
# 3                3  200901BS70004    2021-01-05      Monday
# 4                4  200901BS70005    2021-01-06     Tuesday
# ...            ...            ...           ...         ...
# 168296      168296  201001GD10329    2022-05-04     Tuesday
# 168297      168297  201001GD10330    2022-05-25     Tuesday
# 168298      168298  201001GD10331    2022-05-26   Wednesday
# 168299      168299  201001GD10332    2022-05-12   Wednesday
# 168300      168300  201001GD10334    2022-05-26   Wednesday
#
#                             Junction_Detail Accident_Injuries  \
# 0                   T or staggered junction           Serious
# 1                                Crossroads           Serious
# ...

# %%
dados["Speed_limit"] # Colchetes [] filtram base por coluna
# Out:
# 0         30.0
# 1         30.0
# 2         30.0
# 3         30.0
# 4         30.0
#           ...
# 168296    30.0
# 168297    30.0
# 168298    30.0
# 168299    30.0
# 168300    30.0
# Name: Speed_limit, Length: 168301, dtype: float64

# %%
dados["Speed_limit"].value_counts()
# Out:
# Speed_limit
# 30.0    110080
# 60.0     26093
# 40.0     13580
# 70.0     11680
# 50.0      5345
# 20.0      1519
# 10.0         2
# 15.0         2
# Name: count, dtype: int64

# %%
dados["Speed_limit"].unique()
# Out:
# array([30., 20., 50., 40., 70., 60., 10., 15.])

# %%
dados["Speed_limit"].describe()
# Out:
# count    168301.000000
# mean         38.778498
# std          13.971202
# min          10.000000
# 25%          30.000000
# 50%          30.000000
# 75%          50.000000
# max          70.000000
# Name: Speed_limit, dtype: float64

# %%
dados[dados["Speed_limit"] == 30]
# Out:
#         Unnamed: 0    Accident_ID Accident Date Day_of_Week  \
# 0                0  200901BS70001    2021-01-01    Thursday
# 1                1  200901BS70002    2021-01-05      Monday
# 2                2  200901BS70003    2021-01-04      Sunday
# 3                3  200901BS70004    2021-01-05      Monday
# 4                4  200901BS70005    2021-01-06     Tuesday
# ...            ...            ...           ...         ...
# 168296      168296  201001GD10329    2022-05-04     Tuesday
# 168297      168297  201001GD10330    2022-05-25     Tuesday
# 168298      168298  201001GD10331    2022-05-26   Wednesday
# 168299      168299  201001GD10332    2022-05-12   Wednesday
# 168300      168300  201001GD10334    2022-05-26   Wednesday
#
#                             Junction_Detail Accident_Injuries  \
# 0                   T or staggered junction           Serious
# 1                                Crossroads           Serious
# ...

# %%
dados[dados["Speed_limit"] < 30]
# Out:
#         Unnamed: 0    Accident_ID Accident Date Day_of_Week  \
# 27              27  200901BS70033    2021-01-31    Saturday
# 1508          1508  200901CW10790    2021-05-01      Friday
# 1710          1710  200901CW11050    2021-06-03   Wednesday
# 2003          2003  200901CW11457    2021-07-20      Monday
# 2259          2259  200901CW11822    2021-09-07      Monday
# ...            ...            ...           ...         ...
# 165571      165571  201001CW11315    2022-07-02      Friday
# 165648      165648  201001CW11425    2022-07-14   Wednesday
# 165649      165649  201001CW11426    2022-07-14   Wednesday
# 166882      166882  201001EO40187    2022-03-10   Wednesday
# 166896      166896  201001EO40202    2022-04-20     Tuesday
#
#                             Junction_Detail Accident_Injuries  \
# 27                               Crossroads            Slight
# 1508                T or staggered junction             Fatal
# ...

# %%
dados[(dados["Speed_limit"] < 30)&(dados['Light_Conditions'] == 'Daylight')]
# Out:
#         Unnamed: 0    Accident_ID Accident Date Day_of_Week  \
# 27              27  200901BS70033    2021-01-31    Saturday
# 1508          1508  200901CW10790    2021-05-01      Friday
# 1710          1710  200901CW11050    2021-06-03   Wednesday
# 2003          2003  200901CW11457    2021-07-20      Monday
# 2259          2259  200901CW11822    2021-09-07      Monday
# ...            ...            ...           ...         ...
# 165571      165571  201001CW11315    2022-07-02      Friday
# 165648      165648  201001CW11425    2022-07-14   Wednesday
# 165649      165649  201001CW11426    2022-07-14   Wednesday
# 166882      166882  201001EO40187    2022-03-10   Wednesday
# 166896      166896  201001EO40202    2022-04-20     Tuesday
#
#                             Junction_Detail Accident_Injuries  \
# 27                               Crossroads            Slight
# 1508                T or staggered junction             Fatal
# ...

# %%
lista =['dadada',222,5] #Lista

# %%
idades = {"Daniel":19,"Serena":21} #Dicionario

# %%
idades['Serena']#Consulta de dicionario
# Out:
# 21

# %%
dados.replace({"Daylight":"Day"}) #Substituição dos valores
# Out:
#         Unnamed: 0    Accident_ID Accident Date Day_of_Week  \
# 0                0  200901BS70001    2021-01-01    Thursday
# 1                1  200901BS70002    2021-01-05      Monday
# 2                2  200901BS70003    2021-01-04      Sunday
# 3                3  200901BS70004    2021-01-05      Monday
# 4                4  200901BS70005    2021-01-06     Tuesday
# ...            ...            ...           ...         ...
# 168296      168296  201001GD10329    2022-05-04     Tuesday
# 168297      168297  201001GD10330    2022-05-25     Tuesday
# 168298      168298  201001GD10331    2022-05-26   Wednesday
# 168299      168299  201001GD10332    2022-05-12   Wednesday
# 168300      168300  201001GD10334    2022-05-26   Wednesday
#
#                             Junction_Detail Accident_Injuries  \
# 0                   T or staggered junction           Serious
# 1                                Crossroads           Serious
# ...

# %%
len(dados['Hour_of_Accident'].unique())
# Out:
# 24

# %%
dados['Hour_of_Accident'].value_counts().
# Out:
# Hour_of_Accident
# 17.0    14707
# 16.0    13521
# 15.0    13149
# 8.0     12039
# 18.0    11630
# 13.0    10421
# 14.0    10305
# 12.0     9870
# 19.0     8837
# 11.0     8796
# 9.0      8547
# 10.0     7417
# 7.0      6702
# 20.0     6388
# 21.0     5281
# 22.0     4534
# 23.0     3614
# 6.0      2782
# 0.0      2645
# 1.0      2019
# 2.0      1507
# 5.0      1322
# 3.0      1313
# 4.0       955
# Name: count, dtype: int64

# %%
dados['death_toll'].unique()
# Out:
# array([ 1., 11.,  3.,  2.,  4.,  5.,  6., 10.,  8.,  7.,  9., 13., 12.,
#        14., 16., 18., 15., 19., 21., 17., 27., 48.])

# %%
dados['Number_of_Vehicles'].unique()
# Out:
# array([ 2.,  1.,  3.,  4.,  5.,  9.,  6.,  8.,  7., 10., 16., 13., 14.,
#        11., 12., 32.])

# %%
for i in dados['Hour_of_Accident']:
  if (i <= 3) &(i >= 0):
   dados['Hour_of_Accident'] =  dados['Hour_of_Accident'].replace({i:"0-3"})
  if (i <= 6) & (i > 3 ):
    dados ['Hour_of_Accident'] =  dados['Hour_of_Accident'].replace({i:"3-6"})
  if (i <= 9) & (i > 6):
    dados ['Hour_of_Accident'] =  dados['Hour_of_Accident'].replace({i:"6-9"})
  if (i <= 12) & (i > 9):
    dados ['Hour_of_Accident'] =  dados['Hour_of_Accident'].replace({i:"9-12"})
  if (i <= 15) & (i > 12):
    dados ['Hour_of_Accident'] =  dados['Hour_of_Accident'].replace({i:"12-15"})
  if (i <= 18) & (i > 15):
    dados ['Hour_of_Accident'] =  dados['Hour_of_Accident'].replace({i:"15-18"})
  if (i <= 21) & (i > 18):
    dados ['Hour_of_Accident'] =  dados['Hour_of_Accident'].replace({i:"18-21"})
  if (i <= 24) & (i > 21):
    dados ['Hour_of_Accident'] =  dados['Hour_of_Accident'].replace({i:"21-24"})
# Out:
# <ipython-input-67-ec6c994a2563>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados ['Hour_of_Accident'] =  dados['Hour_of_Accident'].replace({i:"12-15"})
# <ipython-input-67-ec6c994a2563>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados ['Hour_of_Accident'] =  dados['Hour_of_Accident'].replace({i:"9-12"})
# <ipython-input-67-ec6c994a2563>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %% [markdown]
# # Remoção de Outliers

# %%
dados
# Out:
#         Unnamed: 0    Accident_ID Accident Date Day_of_Week  \
# 0                0  200901BS70001    2021-01-01    Thursday
# 1                1  200901BS70002    2021-01-05      Monday
# 2                2  200901BS70003    2021-01-04      Sunday
# 3                3  200901BS70004    2021-01-05      Monday
# 4                4  200901BS70005    2021-01-06     Tuesday
# ...            ...            ...           ...         ...
# 168296      168296  201001GD10329    2022-05-04     Tuesday
# 168297      168297  201001GD10330    2022-05-25     Tuesday
# 168298      168298  201001GD10331    2022-05-26   Wednesday
# 168299      168299  201001GD10332    2022-05-12   Wednesday
# 168300      168300  201001GD10334    2022-05-26   Wednesday
#
#                             Junction_Detail Accident_Injuries  \
# 0                   T or staggered junction           Serious
# 1                                Crossroads           Serious
# ...

# %%
dados ['death_toll'].value_counts()
# Out:
# death_toll
# 1.0     129048
# 2.0      26985
# 3.0       7728
# 4.0       2846
# 5.0       1037
# 6.0        390
# 7.0        123
# 8.0         57
# 9.0         23
# 10.0        22
# 12.0         8
# 11.0         8
# 13.0         7
# 14.0         6
# 18.0         4
# 21.0         3
# 16.0         1
# 15.0         1
# 19.0         1
# 17.0         1
# 27.0         1
# 48.0         1
# Name: count, dtype: int64

# %%
dados['Vehicle_Type'].unique()
# Out:
# array(['Car', 'Taxi', 'Motorcycle', 'Van', 'Other', 'Bus', 'Pedal cycle',
#        'Ridden horse'], dtype=object)

# %%
dados [(dados ['death_toll'] > 10)&(dados['Number_of_Vehicles'] < 2)]['Vehicle_Type'] #mais de 10 mortes em acidentes envolvendo 1 veículo
# Out:
# 26567     Car
# 45818     Car
# 60680     Car
# 69214     Car
# 90411     Car
# 131785    Van
# Name: Vehicle_Type, dtype: object

# %%
dados [(dados ['death_toll'] > 10)&(dados['Number_of_Vehicles'] < 2)].index
# Out:
# Index([26567, 45818, 60680, 69214, 90411, 131785], dtype='int64')

# %%
dados = dados.drop([26567, 45818, 60680, 69214, 90411, 131785])

# %%
dados[26565:26569] #conferindo
# Out:
#        Unnamed: 0    Accident_ID Accident Date Day_of_Week  \
# 26565       26565  200904CJ09066    2021-10-10    Saturday
# 26566       26566  200904CJ09067    2021-10-08    Thursday
# 26568       26568  200904CJ09069    2021-10-21   Wednesday
# 26569       26569  200904CJ09070    2021-10-22    Thursday
#
#                            Junction_Detail Accident_Injuries Light_Conditions  \
# 26565              T or staggered junction            Slight         Daylight
# 26566                           Roundabout            Slight         Daylight
# 26568  Not at junction or within 20 metres           Serious         Daylight
# 26569              T or staggered junction            Slight         Daylight
#
#        death_toll  Number_of_Vehicles Road_Surface_Conditions  \
# 26565         1.0                 2.0                     Dry
# 26566         1.0                 2.0                     Dry
# 26568         1.0                 2.0                     Dry
# ...
